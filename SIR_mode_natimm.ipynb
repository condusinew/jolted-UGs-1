# %% [markdown]
# <a href="https://colab.research.google.com/github/condusinew/jolted-UGs-1/blob/main/SIR_mode_natimm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# $\frac{\mathrm{d}S}{\mathrm{d}t} = -(\beta_r I_r + \beta_v I_v)S$
#
# $\frac{\mathrm{d}I_r}{\mathrm{d}t} = \beta_r I_r [S+N+(1-\epsilon_L) P] - \gamma_r I_r $
#
# $\frac{\mathrm{d}N}{\mathrm{d}t} = (1-\epsilon_a)\gamma_rI_r - (\beta_v I_v + \beta_r I_r) N $
#
# $\frac{\mathrm{d}P}{\mathrm{d}t} = \epsilon_a\gamma_rI_r - \beta_r I_r(1-\epsilon_L)P - \beta_v I_v (1-(1-\mu)\epsilon_L) P$
#
# $\frac{\mathrm{d}I_v}{\mathrm{d}t} = \beta_v I_v [S + N + (1-(1-\mu)\epsilon_L)] P - \gamma_v I_v$
#
# $\frac{\mathrm{d}R_v}{\mathrm{d}t} = \gamma_v I_v$

# %% [markdown]
# ###must run

# %%
import numpy as np
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
# @title
# SIR model equations


def SIR_model_rv(t, y, mu, betaw, gammaw, betam, gammam, epsilona, epsilonL):
    S, Iw, N, P, Im, Rm, CIw, CIm  = y


    dSdt = -(betaw*Iw+ betam*Im) * S
    dIwdt = betaw * Iw* (S + N + (1-epsilonL)*P)  - gammaw * Iw

    dNdt = (1-epsilona)*gammaw * Iw - (betam*Im+betaw*Iw) *N
    dPdt = epsilona * gammaw * Iw-betaw*Iw*(1-epsilonL)*P - betam*Im*(1-((1-mu)*epsilonL))*P

    dImdt = betam*Im*(S + N +(1-((1-mu)*epsilonL))*P) - gammam * Im
    dRmdt = gammam * Im

    #will include indImiduals that get reinfected as multiple infections
    #cumulatIme infections
    dCIwdt = betaw * Iw* (S + N + (1-epsilonL)*P)
    dCImdt = betam*Im*(S + N +(1-((1-mu)*epsilonL))*P)

    return [dSdt, dIwdt, dNdt, dPdt, dImdt, dRmdt, dCIwdt, dCImdt]

# basic plot to show compartment prevalence across time
def plot_basic(solution, ax=None, title="SIR sim w variant", ylim_max = 1):
    if ax is None:
        fig, ax = plt.subplots()

    t = solution.t
    S, Iw, N, P, Im, Rm, CIw, CIm = solution.y

    ax.plot(t, S, label='Susceptible')
    ax.plot(t, Iw, label='Infected (wildtype)')
    ax.plot(t, Im, label='Infected (mutant)')
    ax.plot(t, Rm, label='Recovered (mutant)')
    ax.plot(t, N, label='Immunity_none')
    ax.plot(t, P, label='Immunity_leaky')

    ax.set_xlabel('Time (days)')
    ax.set_ylabel('Proportion of Population')
    ax.set_title(title)
    ax.set_ylim(0, ylim_max)
    ax.legend()
    ax.grid(True)

    return ax

def plot_cum(solution, ax=None, title="Cumulative infections", ylim_max = 1):
    if ax is None:
        fig, ax = plt.subplots()

    t = solution.t
    *_, CIw, CIm = solution.y

    ax.plot(t, CIw, label="Cumulative WT")
    ax.plot(t, CIm, label="Cumulative variant")

    ax.set_xlabel("Time (days)")
    ax.set_ylabel("Cumulative incidence")
    ax.set_title(title)
    ax.set_ylim(0, ylim_max)
    ax.legend()
    ax.grid(True)

    return ax


#find final cumulative infections (gonna multiply this for total infected)
def find_finalCIw(solution):
  t = solution.t
  S, Iw, N, P, Im, Rm, CIw, CIm  = solution.y
  return(CIw[-1])

def find_finalCIm(solution):
  t = solution.t
  S, Iw, N, P, Im, Rm, CIw, CIm  = solution.y
  return(CIm[-1])

#find whether it is a one wave epidemic or endemic equil
def Iw_wave_or_end(solution):
  S, Iw, N, P, Im, Rm, CIw, CIm  = solution.y

  if Iw[-1] > 0.02: #MAYBE CHANGE THIS IF NEEDED DEPENDING ON WHAT GRAPHS SHOW
    return "endemic"

  else:
    return "wave"

def find_Iw_peak(solution, wave_or_end: str):
  S, Iw, N, P, Im, Rm, CIw, CIm  = solution.y

  if wave_or_end == "wave":
    return max(Iw)

  else:
    return pd.NA

def find_Iw_equil(solution, wave_or_end: str):
  S, Iw, N, P, Im, Rm, CIw, CIm  = solution.y

  if wave_or_end == "endemic":
    return Iw[-1]

  else:
    return pd.NA

def Im_wave_or_end(solution):
  S, Iw, N, P, Im, Rm, CIw, CIm  = solution.y

  if Iw[-1] > 0.02: #MAYBE CHANGE THIS IF NEEDED DEPENDING ON WHAT GRAPHS SHOW
    return "endemic"

  else:
    return "wave"

def find_Im_peak(solution, wave_or_end: str):
  S, Iw, N, P, Im, Rm, CIw, CIm  = solution.y

  if wave_or_end == "wave":
    return max(Im)

  else:
    return pd.NA

def find_Im_equil(solution, wave_or_end: str):
  S, Iw, N, P, Im, Rm, CIw, CIm  = solution.y

  if wave_or_end == "endemic":
    return Im[-1]

  else:
    return pd.NA

#function for plotting infected for many epsilons. two means 2 subplots
def plot_many_eps(two = True, figsize=(15, 6), ylim_max = 1, **kwargs):
  #must send kwargs as a dictionary with epsilon_a as as keys, values being a list of epsilon_l and solution

  fig = plt.figure(facecolor="w", figsize=figsize)

  #resident subplot
  ax1 = fig.add_subplot(121, axisbelow=True)
  if two == True:
    ax2 = fig.add_subplot(122, axisbelow=True)


  for epsA_key, eps_solut in kwargs.items():
    S, Iw, N, P, Im, Rm, CIw, CIm = eps_solut[1].y #takes solution (index 1) out from list
    t = eps_solut[1].t

    label = "epsilon_a = " + epsA_key + ", epsilon_L = " + eps_solut[0]
    ax1.plot(t, Iw, label=label, alpha=0.5)
    if two == True:
      ax2.plot(t, Im, label=label, alpha=0.5)

  ax1.set_xlabel('Time (days)')
  ax1.set_ylabel('Prevalence of resident')
  ax1.set_ylim(0,ylim_max)
  ax1.grid(linewidth=0.5)
  legend = ax1.legend()
  legend.get_frame().set_alpha(0.5)

  if two == True:
    ax2.set_xlabel('Time (days)')
    ax2.set_ylabel('Prevalence of variant')
    ax2.set_ylim(0,ylim_max)
    ax2.grid(linewidth=0.5)
    legend = ax2.legend()
    legend.get_frame().set_alpha(0.5)


#function for plotting any two compartment curves (eg. Iw) for many scenarios, with only one (hence mono) specified param (eg. mu) being modulated
def plot_many_mono_anytwo(param, compartment1 = "Iw", compartment2 = "Im", figsize=(15, 6), ylim_max = 1, **kwargs):
  #must send kwargs as a dictionary with (param val) as as keysn, values being solutions

  fig = plt.figure(facecolor="w", figsize=figsize)

  #resident subplot
  ax1 = fig.add_subplot(121, axisbelow=True)
  ax2 = fig.add_subplot(122, axisbelow=True)

  for key, solution in kwargs.items():
    S, Iw, N, P, Im, Rm, CIw, CIm =  solution.y #takes solution out from list
    t = solution.t

    curves = {
            "S": S,
            "Iw": Iw,
            "N": N,
            "P": P,
            "Im": Im,
            "Rm": Rm
        }

    label = f"{param} = {key}"
    ax1.plot(t, curves[compartment1], label=label, alpha=0.5)
    ax2.plot(t, curves[compartment2], label=label, alpha=0.5)

  ax1.set_xlabel('Time (days)')
  ax1.set_ylabel((f"{compartment1}"))
  ax1.set_ylim(0,ylim_max)
  ax1.grid(linewidth=0.5)
  legend = ax1.legend()
  legend.get_frame().set_alpha(0.5)

  ax2.set_xlabel('Time (days)')
  ax2.set_ylabel(f"{compartment2}")
  ax2.set_ylim(0,ylim_max)
  ax2.grid(linewidth=0.5)
  legend = ax2.legend()
  legend.get_frame().set_alpha(0.5)


#function for plotting ONE compartment curves (eg. Iw) for many scenarios, with only one (hence mono) specified param (eg. mu) being modulated
def plot_many_mono_one(param: str, compartment: str, figsize=(15, 6), ylim_max = 1, **kwargs):
  #must send kwargs as a dictionary with (param val) as as keysn, values being solutions
    fig= plt.figure(facecolor="w", figsize=figsize)
    ax1 = fig.add_subplot(121, axisbelow=True)

    for key, solution in kwargs.items():
        S, Iw, N, P, Im, Rm, CIw, CIm =  solution.y
        t = solution.t

        curves = {
            "S": S,
            "Iw": Iw,
            "N": N,
            "P": P,
            "Im": Im,
            "Rm": Rm
        }

        label = f"{param} = {key}"
        ax1.plot(t, curves[compartment], label=label, alpha=0.5)

    ax1.set_xlabel("Time (days)")
    ax1.set_ylabel(f"{compartment}")
    ax1.set_ylim(0, ylim_max)
    ax1.grid(linewidth=0.5)
    legend = ax1.legend()
    legend.get_frame().set_alpha(0.5)

    plt.show()



#SIMILAR TO ABOVE PLOTS BUT FOR RELATImE FREQUENCY ONLY

#function for plotting infected for many epsilons
def plot_many_Mprop(figsize=(15, 6), ylim_max = 1, **kwargs):
  #must send kwargs as a dictionary with epsilon_a as as keys, values being a list of epsilon_l and solution

  fig = plt.figure(facecolor="w", figsize=figsize)

  #resident subplot
  ax1 = fig.add_subplot(121, axisbelow=True)

  for epsilon_a, eps_solut in kwargs.items():
    S, Iw, N, P, Im, Rm, CIw, CIm =  eps_solut[1].y #takes solution (index 1) out from list
    t = eps_solut[1].t

    M_prop = Im/(Iw+Im)
    label = "epsilon_a = " + epsilon_a + ", epsilon_L = " + eps_solut[0]
    ax1.plot(t, M_prop, label=label, alpha=0.5)


  ax1.set_xlabel('Time (days)')
  ax1.set_ylabel('Im/Iw')
  ax1.set_ylim(0,ylim_max)
  ax1.grid(linewidth=0.5)
  legend = ax1.legend()
  legend.get_frame().set_alpha(0.5)


def plot_many_mono_Mprop(param: str, figsize=(15, 6), ylim_max = 1, **kwargs):
  #must send kwargs as a dictionary with (param val) as as keysn, values being solutions
    fig = plt.figure(facecolor="w", figsize=figsize)
    ax1 = fig.add_subplot(121, axisbelow=True)

    for key, solution in kwargs.items():
        S, Iw, N, P, Im, Rm, CIw, CIm =  solution.y

        t = solution.t

        M_prop = Im/(Iw+Im)

        label = f"{param} = {key}"
        ax1.plot(t, M_prop, label=label, alpha=0.5)

    ax1.set_xlabel("Time (days)")
    ax1.set_ylabel("Im/Iw")
    ax1.set_ylim(-0.1, ylim_max)
    ax1.grid(linewidth=0.5)
    legend = ax1.legend()
    legend.get_frame().set_alpha(0.5)

    plt.show()

# %%
#ALWAYS RUN
CIm0 = 0
CIw0 = 0

# %% [markdown]
# #Stress-Testing Scenarios

# %% [markdown]
# ##1. Basic SIR model with perfect natural immunity only
# P as the absorbing compartment. Behaviour should resemble SIR model, with P as traditional R. Final epidemic size is affected by R0. If R0 is kept constant, changes in recovery should not change final epidemic size. Rate of increase of epidemic (as seen in P and Iw) is influenced by beta and indIwectly affected by R0 and recovery rate.

# %%
# set parameter values
#betaw = 1.1
Rwnaught = 1.6
gammaw = 1/14
betaw = gammaw*Rwnaught

#Rwnaught = betaw / gammaw # R0 for residents with entIwely susceptible population


betam = 1
gammam = 1
Rmnaught = betam / gammam # R0 for variant with entIwely susceptible population

mu = 0.6
epsilona = 1
epsilonL = 1
t = 1000

# set initial conditions
S0 = 0.999
Iw0 = 0.001

N0 = 0
P0 = 0

Rm0 = 0
Im0 = 1-(S0+Iw0+N0+P0+Rm0) #need to get this seeded later

if (S0+Iw0+Im0+Rm0+N0+P0) != 1 or Im0 < 0:
  print("Parameters don't add up to 1 or there are negatIme parameter values")

y0 = [S0, Iw0, N0, P0, Im0, Rm0, CIw0, CIm0]
# Solve the SIR model equations using odeint()
solution = solve_ivp(SIR_model_rv,
                     [0,t],
                     y0,
                     args=(mu, betaw, gammaw, betam, gammam, epsilona, epsilonL),
                     dense_output=True,
                     t_eval=np.linspace(0, t, t + 1),)

plot_basic(solution)
# Out:
# <Axes: title={'center': 'SIR sim w variant'}, xlabel='Time (days)', ylabel='Proportion of Population'>

# %% [markdown]
# ## 2. One strain model with no natural immunity using N compartment
#
# N as the recovery compartment, meaning full susceptibility. Pe eventually reach an equilibrium state where rate of recovery matches rate of transmission, but infection never dies out..
#
#
# Final epidemic size is affected by R0. If R0 is kept constant, changes in recovery should not change final epidemic size. Rate of increase of epidemic (as seen in P and Iw) is influenced by beta and indIwectly affected by R0 and recovery rate.

# %%
# set parameter values
#betaw = 1.1
Rwnaught = 1.6
gammaw = 1/14
betaw = gammaw*Rwnaught
#Rwnaught = betaw / gammaw # R0 for residents with entIwely susceptible population


betam = 1
gammam = 1
Rmnaught = betam / gammam # R0 for variant with entIwely susceptible population

mu = 0.6
epsilona = 0
epsilonL = 1
t = 1000

# set initial conditions
S0 = 0.999
Iw0 = 0.001

N0 = 0
P0 = 0

Rm0 = 0
Im0 = 1-(S0+Iw0+N0+P0+Rm0) #need to get this seeded later


if (S0+Iw0+Im0+Rm0+N0+P0) != 1 or Im0 < 0:
  print("Parameters don't add up to 1 or there are negatIme parameter values")

y0 = [S0, Iw0, N0, P0, Im0, Rm0, CIw0, CIm0]

# Solve the SIR model equations using odeint()
solution = solve_ivp(SIR_model_rv,
                     [0,t],
                     y0,
                     args=(mu, betaw, gammaw, betam, gammam, epsilona, epsilonL),
                     dense_output=True,
                     t_eval=np.linspace(0, t, t + 1),)

plot_basic(solution)
# Out:
# <Axes: title={'center': 'SIR sim w variant'}, xlabel='Time (days)', ylabel='Proportion of Population'>

# %% [markdown]
# ## 2.5 One strain model with no natural immunity
#
# P as the only recovery compartment, but with epsilonL = 0, meaning full susceptibility. Pe eventually reach an equilibrium state where rate of recovery matches rate of transmission, but infection never dies out. Behaviour should match the previous scenario exactly when params are the same as well. **SIS
#
#
# Final epidemic size is affected by R0. If R0 is kept constant, changes in recovery should not change final epidemic size. Rate of increase of epidemic (as seen in P and Iw) is influenced by beta and indIwectly affected by R0 and recovery rate.

# %%
# set parameter values
#betaw = 1.1
Rwnaught = 1.6
gammaw = 1/14
betaw = gammaw*Rwnaught
#Rwnaught = betaw / gammaw # R0 for residents with entIwely susceptible population


betam = 1
gammam = 1
Rmnaught = betam / gammam # R0 for variant with entIwely susceptible population

mu = 0.6
epsilona = 1
epsilonL = 0 #0
t = 1000

# set initial conditions
S0 = 0.999
Iw0 = 0.001

N0 = 0
P0 = 0

Rm0 = 0
Im0 = 1-(S0+Iw0+N0+P0+Rm0) #need to get this seeded later


if (S0+Iw0+Im0+Rm0+N0+P0) != 1 or Im0 < 0:
  print("Parameters don't add up to 1 or there are negatIme parameter values")

y0 = [S0, Iw0, N0, P0, Im0, Rm0, CIw0, CIm0]

# Solve the SIR model equations using odeint()
solution = solve_ivp(SIR_model_rv,
                     [0,t],
                     y0,
                     args=(mu, betaw, gammaw, betam, gammam, epsilona, epsilonL),
                     dense_output=True,
                     t_eval=np.linspace(0, t, t + 1),)

plot_basic(solution)
# Out:
# <Axes: title={'center': 'SIR sim w variant'}, xlabel='Time (days)', ylabel='Proportion of Population'>

# %% [markdown]
# ## 3. *One strain model with leaky immunity only
#
# P as the recovery compartment, with leaky susceptibility 0 < epsilon_L < 1. Infection eventually dies out unless at high leakiness (epsilon_L closer to 0).
#
# Unlike prior models, where infection dies out because there is nobody left susceptible, infection dying out is contingent on the infected compartment reaching 0 as there is no absorbing compartment.
#
# Final epidemic size is affected by R0. If R0 is kept constant, changes in recovery should not change final epidemic size. Rate of increase of epidemic (as seen in P and Iw) is influenced by beta and indIwectly affected by R0 and recovery rate.

# %%
# set parameter values
#betaw = 1.1
Rwnaught = 1.6
gammaw = 1/14
betaw = 1/2 #gammaw*Rwnaught
#Rwnaught = betaw / gammaw # R0 for residents with entIwely susceptible population

betam = 1
gammam = 1
Rmnaught = betam / gammam # R0 for variant with entIwely susceptible population

mu = 0.6
epsilona = 1
epsilonL = 0.25
t = 300

# set initial conditions
S0 = 0.999
Iw0 = 0.001

N0 = 0
P0 = 0

Rm0 = 0
Im0 = 1-(S0+Iw0+N0+P0+Rm0) #need to get this seeded later


if (S0+Iw0+Im0+Rm0+N0+P0) != 1 or Im0 < 0:
  print("Parameters don't add up to 1 or there are negatIme parameter values")

y0 = [S0, Iw0, N0, P0, Im0, Rm0, CIw0, CIm0]

# Solve the SIR model equations using odeint()
solution = solve_ivp(SIR_model_rv,
                     [0,t],
                     y0,
                     args=(mu, betaw, gammaw, betam, gammam, epsilona, epsilonL),
                     dense_output=True,
                     t_eval=np.linspace(0, t, t + 1),)

plot_basic(solution)
# Out:
# <Axes: title={'center': 'SIR sim w variant'}, xlabel='Time (days)', ylabel='Proportion of Population'>

# %% [markdown]
# ## 4. *One strain model with all or nothing protection. epsilon_A = 0.5
#
#
# Infection dies out because more and more are absorbed into P, perfect protection compartment. This can be seen as P's curve grows visibly more and for longer comparted to N, matching the decrease in infected. Population gradually becomes less susceptible until Iw= 0. Note people in N are still susceptible, though P outweighs N due to P's perfect protection.
#
# Final epidemic size is affected by R0. If R0 is kept constant, changes in recovery should not change final epidemic size. Rate of increase of epidemic (as seen in P and Iw) is influenced by beta and indIwectly affected by R0 and recovery rate.

# %%
# set parameter values
#betaw = 1.1
Rwnaught = 1.6
gammaw = 1/14
betaw = gammaw*Rwnaught
#Rwnaught = betaw / gammaw # R0 for residents with entIwely susceptible population


betam = 1
gammam = 1
Rmnaught = betam / gammam # R0 for variant with entIwely susceptible population

mu = 0.6
epsilona = 0.1
epsilonL = 1
t = 1000

# set initial conditions
S0 = 0.999
Iw0 = 0.001

N0 = 0
P0 = 0

Rm0 = 0
Im0 = 1-(S0+Iw0+N0+P0+Rm0) #need to get this seeded later


if (S0+Iw0+Im0+Rm0+N0+P0) != 1 or Im0 < 0:
  print("Parameters don't add up to 1 or there are negatIme parameter values")

y0 = [S0, Iw0, N0, P0, Im0, Rm0, CIw0, CIm0]

# Solve the SIR model equations using odeint()
solution = solve_ivp(SIR_model_rv,
                     [0,t],
                     y0,
                     args=(mu, betaw, gammaw, betam, gammam, epsilona, epsilonL),
                     dense_output=True,
                     t_eval=np.linspace(0, t, t + 1),)

plot_basic(solution)
# Out:
# <Axes: title={'center': 'SIR sim w variant'}, xlabel='Time (days)', ylabel='Proportion of Population'>

# %% [markdown]
# ## 5. *One strain model with 2 modes of imperfect protection: leaky [epsilon_L ϵ (0,1) ] and no natural immunity. epsilon_A = 0.5
#
#
# Infection doesn't die out because (gammaR)(Iw) = BrIw(S+N+(1-Ea)P) —that is, recovery rates match transmission.
#
#
# Final epidemic size is affected by R0. If R0 is kept constant, changes in recovery should not change final epidemic size. Rate of increase of epidemic (as seen in P and Iw) is influenced by beta and indIwectly affected by R0 and recovery rate.

# %%
# set parameter values
#betaw = 1.1
Rwnaught = 1.6
gammaw = 1/14
betaw = gammaw*Rwnaught
#Rwnaught = betaw / gammaw # R0 for residents with entIwely susceptible population


betam = 1
gammam = 1
Rmnaught = betam / gammam # R0 for variant with entIwely susceptible population

mu = 0.6
epsilona = 0.5
epsilonL = 0.5
t = 2000

# set initial conditions
S0 = 0.999
Iw0 = 0.001

N0 = 0
P0 = 0

Rm0 = 0
Im0 = 1-(S0+Iw0+N0+P0+Rm0) #need to get this seeded later


if (S0+Iw0+Im0+Rm0+N0+P0) != 1 or Im0 < 0:
  print("Parameters don't add up to 1 or there are negatIme parameter values")

y0 = [S0, Iw0, N0, P0, Im0, Rm0, CIw0, CIm0]


solution = solve_ivp(SIR_model_rv,
                     [0,t],
                     y0,
                     args=(mu, betaw, gammaw, betam, gammam, epsilona, epsilonL),
                     dense_output=True,
                     t_eval=np.linspace(0, t, t + 1),)

plot_basic(solution)
# Out:
# <Axes: title={'center': 'SIR sim w variant'}, xlabel='Time (days)', ylabel='Proportion of Population'>

# %% [markdown]
# ## 6. Two-strain model, variant exists at t = 0. Natural immunity confers perfect protection against all variants (mu = 0, epsilonL = 1, epsilonA = 1).
#
# Similar to equImalent one-strain model, but both P and R_v absorbs all.
#
# Final epidemic size seems unaffected by changes in mu, but there are changes in P compartment

# %%
# set parameter values
#betaw = 1.1
Rwnaught = 1.6
gammaw = 1/14
betaw = gammaw*Rwnaught
#Rwnaught = betaw / gammaw # R0 for residents with entIwely susceptible population


Rmnaught = 1.7
gammam = 1/14
betam = Rmnaught*gammam
#Rmnaught = betam / gammam # R0 for variant with entIwely susceptible population

mu = 0
epsilona = 1
epsilonL = 1
t = 1000

# set initial conditions
S0 = 0.999
Iw0 = 0.0009

N0 = 0
P0 = 0

Rm0 = 0
Im0 = 1-(S0+Iw0+N0+P0+Rm0) #need to get this seeded later


if (S0+Iw0+Im0+Rm0+N0+P0) != 1 or Im0 < 0:
  print("Parameters don't add up to 1 or there are negatIme parameter values")

y0 = [S0, Iw0, N0, P0, Im0, Rm0, CIw0, CIm0]

# Solve the SIR model equations using odeint()
solution = solve_ivp(SIR_model_rv,
                     [0,t],
                     y0,
                     args=(mu, betaw, gammaw, betam, gammam, epsilona, epsilonL),
                     dense_output=True,
                     t_eval=np.linspace(0, t, t + 1),)

plot_basic(solution)
# Out:
# <Axes: title={'center': 'SIR sim w variant'}, xlabel='Time (days)', ylabel='Proportion of Population'>

# %% [markdown]
# ## 7. Two-strain model, variant exists at t=0. Natural immunity confers no protection against any variants, all go to N.
#
# Pill see a lot more R_v compared to previous scenario, as the only absorbing compartment. Infected reaches higher final epidemic size and faster as more of the population stays susceptible for longer compared to previous scenario 6.

# %%
# set parameter values
#betaw = 1.1
Rwnaught = 1.6
gammaw = 1/14
betaw = gammaw*Rwnaught
#Rwnaught = betaw / gammaw # R0 for residents with entIwely susceptible population


Rmnaught = 1.7
gammam = 1/14
betam = Rmnaught*gammam
#Rmnaught = betam / gammam # R0 for variant with entIwely susceptible population

mu = 0.6
epsilona = 0
epsilonL = 1
t = 1000

# set initial conditions
S0 = 0.999
Iw0 = 0.0009

N0 = 0
P0 = 0

Rm0 = 0
Im0 = 1-(S0+Iw0+N0+P0+Rm0) #need to get this seeded later


if (S0+Iw0+Im0+Rm0+N0+P0) != 1 or Im0 < 0:
  print("Parameters don't add up to 1 or there are negatIme parameter values")

y0 = [S0, Iw0, N0, P0, Im0, Rm0, CIw0, CIm0]

# Solve the SIR model equations using odeint()
solution = solve_ivp(SIR_model_rv,
                     [0,t],
                     y0,
                     args=(mu, betaw, gammaw, betam, gammam, epsilona, epsilonL),
                     dense_output=True,
                     t_eval=np.linspace(0, t, t + 1),)

plot_basic(solution)
# Out:
# <Axes: title={'center': 'SIR sim w variant'}, xlabel='Time (days)', ylabel='Proportion of Population'>

# %% [markdown]
# ## 8. Two-strain model, variant exists at t=0. All-or-nothing immunity (epsilon_A = 0.5)

# %%
# set parameter values
#betaw = 1.1
Rwnaught = 1.6
gammaw = 1/14
betaw = gammaw*Rwnaught
#Rwnaught = betaw / gammaw # R0 for residents with entIwely susceptible population


Rmnaught = 1.7
gammam = 1/14
betam = Rmnaught*gammam
#Rmnaught = betam / gammam # R0 for variant with entIwely susceptible population

mu = 0.6
epsilona = 0.6
epsilonL = 1
t = 1000

# set initial conditions
S0 = 0.999
Iw0 = 0.0009

N0 = 0
P0 = 0

Rm0 = 0
Im0 = 1-(S0+Iw0+N0+P0+Rm0) #need to get this seeded later


if (S0+Iw0+Im0+Rm0+N0+P0) != 1 or Im0 < 0:
  print("Parameters don't add up to 1 or there are negatIme parameter values")

y0 = [S0, Iw0, N0, P0, Im0, Rm0, CIw0, CIm0]

# Solve the SIR model equations using odeint()
solution_aon = solve_ivp(SIR_model_rv,
                     [0,t],
                     y0,
                     args=(mu, betaw, gammaw, betam, gammam, epsilona, epsilonL),
                     dense_output=True,
                     t_eval=np.linspace(0, t, t + 1),)
plot_basic(solution_aon)
# Out:
# <Axes: title={'center': 'SIR sim w variant'}, xlabel='Time (days)', ylabel='Proportion of Population'>

# %% [markdown]
# ## 9. Two-strain model, variant exists at t=0. Leaky immunity (epsilon_A = 0.0, epsilon_L ϵ (0,1))
#
# Greater epidemic size than all-or-nothing model

# %%
# set parameter values
#betaw = 1.1
Rwnaught = 1.6
gammaw = 1/14
betaw = gammaw*Rwnaught
#Rwnaught = betaw / gammaw # R0 for residents with entIwely susceptible population


Rmnaught = 1.7
gammam = 1/14
betam = Rmnaught*gammam
#Rmnaught = betam / gammam # R0 for variant with entIwely susceptible population

mu = 0.6
epsilona = 1#0
epsilonL = 0.2#0.5
t = 1000

# set initial conditions
S0 = 0.999
Iw0 = 0.0009

N0 = 0
P0 = 0

Rm0 = 0
Im0 = 1-(S0+Iw0+N0+P0+Rm0) #need to get this seeded later


if (S0+Iw0+Im0+Rm0+N0+P0) != 1 or Im0 < 0:
  print("Parameters don't add up to 1 or there are negatIme parameter values")

y0 = [S0, Iw0, N0, P0, Im0, Rm0, CIw0, CIm0]

# Solve the SIR model equations using odeint()
solution_leaky = solve_ivp(SIR_model_rv,
                     [0,t],
                     y0,
                     args=(mu, betaw, gammaw, betam, gammam, epsilona, epsilonL),
                     dense_output=True,
                     t_eval=np.linspace(0, t, t + 1),)
plot_basic(solution_leaky)
# Out:
# <Axes: title={'center': 'SIR sim w variant'}, xlabel='Time (days)', ylabel='Proportion of Population'>

# %% [markdown]
# # **MODULATING MU & PLOTTING RELATIVE FREQUENCIES**

# %% [markdown]
# ##SANITY CHECKS

# %%
# set parameter values that will not be changing

Rwnaught = 1.6
gammaw = 1/14
betaw = gammaw*Rwnaught

Rmnaught = Rwnaught
gammam = gammaw
betam = Rmnaught*gammam
#Rmnaught = betam / gammam # R0 for variant with entIwely susceptible population

epsilona = 1 #1 means go into P: all/leaky; 0 means go into N, nothing
epsilonL = 1 #nat imm efficacy
t = 400

# set initial conditions
S0 = 0.999
Iw0 = 0.0005

N0 = 0
P0 = 0

Rm0 = 0
Im0 = 0.0005 #need to get this seeded later

y0 = [S0, Iw0, N0, P0, Im0, Rm0, CIw0, CIm0]

# %%
S0+Iw0+Im0
# Out:
# 0.9999999999999999

# %%
#list of MU
mu = [0, 0.25, 0.5, 0.75, 1] #mu being degre of immune escape, closer to 1 means more escape

kwargs = {}
solutions = []

#loop thru epsilon values and solve to get many solutions at same protection level
for i in range(len(mu)):

  solution = solve_ivp(SIR_model_rv,
                      [0,t],
                      y0,
                      args=(mu[i], betaw, gammaw, betam, gammam, epsilona, epsilonL),
                      dense_output=True,
                      t_eval=np.linspace(0, t, t + 1),)
  solutions.append(solution)
  kwargs[str(mu[i])] = solutions[i]

plot_many_mono_anytwo("mu",ylim_max = 0.20,**kwargs)
plot_many_mono_Mprop("mu",ylim_max = 10,**kwargs)

# %% [markdown]
# #RUNNING DIFF IMMUNITIES - 1 strain

# %%
# set parameter values (except epsilon) for all scenarios
#betaw = 1.1
Rwnaught = 1.6
gammaw = 1/14
betaw = gammaw*Rwnaught
#Rwnaught = betaw / gammaw # R0 for residents with entIwely susceptible population

mu = 0.6
epsilona = 0.1
epsilonL = 1
t = 1000

betam = 1
gammam = 1
Rmnaught = betam / gammam # R0 for variant with entIwely susceptible population

# set initial conditions
S0 = 0.999
Iw0 = 0.001

N0 = 0
P0 = 0

Rm0 = 0
Im0 = 1-(S0+Iw0+N0+P0+Rm0) #need to get this seeded later
y0 = [S0, Iw0, N0, P0, Im0, Rm0, CIw0, CIm0]

# %%
one_strain_df = pd.DataFrame(columns=['overall_immunity', 'epsilon_a', 'epsilon_L', 'mu', 'CIw', 'one-wave or endemic', "peak Iw", 'equil_Iw'])

# %% [markdown]
# ##immunity overall = 1

# %%
epsilona = 1
epsilonL = 1
kwargs = {}

#loop thru epsilon values and solve to get many solutions at same protection level


solution = solve_ivp(SIR_model_rv,
                    [0,t],
                    y0,
                    args=(mu, betaw, gammaw, betam, gammam, epsilona, epsilonL),
                    dense_output=True,
                    t_eval=np.linspace(0, t, t + 1),)

plot_basic(solution)

  #add to df
one_strain_df.loc[len(one_strain_df)] = [epsilona*epsilonL,
                              epsilona,
                              epsilonL,
                              mu,
                              find_finalCIw(solution),
                              Iw_wave_or_end(solution),
                              find_Iw_peak(solution, Iw_wave_or_end(solution)),
                              find_Iw_equil(solution, Iw_wave_or_end(solution))]

# %% [markdown]
# ##immunity overall = 0

# %%
epsilona_vals = [0, 1]
epsilonL_vals = [1, 0]
kwargs = {}
solutions = []

mu = 0.6
#loop thru epsilon values and solve to get many solutions at same protection level
for i in range(len(epsilona_vals)):
  epsilona = epsilona_vals[i]
  epsilonL = epsilonL_vals[i]
  solution = solve_ivp(SIR_model_rv,
                      [0,t],
                      y0,
                      args=(mu, betaw, gammaw, betam, gammam, epsilona, epsilonL),
                      dense_output=True,
                      t_eval=np.linspace(0, t, t + 1),)
  solutions.append(solution)
  kwargs[str(epsilona_vals[i])] = [str(epsilonL_vals[i]), solutions[i]]
  plot_basic(solution)

  #add to df
  one_strain_df.loc[len(one_strain_df)] = [epsilona*epsilonL,
                                epsilona,
                                epsilonL,
                                mu,
                                find_finalCIw(solution),
                                Iw_wave_or_end(solution),
                                find_Iw_peak(solution, Iw_wave_or_end(solution)),
                                find_Iw_equil(solution, Iw_wave_or_end(solution))]



plot_many_eps(two = False, ylim_max = 0.5,**kwargs)
# Out:
# /tmp/ipython-input-299914999.py:22: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   one_strain_df.loc[len(one_strain_df)] = [epsilona*epsilonL,
# /tmp/ipython-input-299914999.py:22: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   one_strain_df.loc[len(one_strain_df)] = [epsilona*epsilonL,

# %%
one_strain_df
# Out:
#    overall_immunity  epsilon_a  epsilon_L   mu        CIw one-wave or endemic  \
# 0                 1          1          1  0.6   0.642548                wave
# 1                 0          0          1  0.6  23.456847             endemic
# 2                 0          1          0  0.6  23.456847             endemic
#
#     peak Iw  equil_Iw
# 0  0.082383       NaN
# 1       NaN     0.375
# 2       NaN     0.375

# %% [markdown]
# ## immunity overall = 0.75

# %% [markdown]
# # **RUNNING DIFF IMMUNITIES - 2 STRAIN**

# %%
# set parameter values (except epsilon) for all scenarios
#betaw = 1.1
Rwnaught = 1.6
gammaw = 1/14
betaw = gammaw*Rwnaught
#Rwnaught = betaw / gammaw # R0 for residents with entIwely susceptible population


#epsilona = 0.1
#epsilonL = 1
mu_all = 0.7
t = 1000

Rmnaught = 1.6
gammam = 1/14
betam = gammam*Rmnaught


 # R0 for variant with entIwely susceptible population

# set initial conditions
S0 = 0.999
Iw0 = 0.0009

N0 = 0
P0 = 0

Rm0 = 0
Im0 = 1-(S0+Iw0+N0+P0+Rm0) #need to get this seeded later
y0 = [S0, Iw0, N0, P0, Im0, Rm0, CIw0, CIm0]

two_strain_df = pd.DataFrame(columns=['overall_immunity', 'epsilon_a', 'epsilon_L', 'mu', 'CIw', "CIm", 'one-wave or endemic', "peak Iw", 'equil_Iw'])

# %% [markdown]
# ## total natural immunity = 1 = E_a*E_L

# %%
epsilona = 1
epsilonL = 1
mu = mu_all
kwargs = {}

#loop thru epsilon values and solve to get many solutions at same protection level


solution = solve_ivp(SIR_model_rv,
                    [0,t],
                    y0,
                    args=(mu, betaw, gammaw, betam, gammam, epsilona, epsilonL),
                    dense_output=True,
                    t_eval=np.linspace(0, t, t + 1),)

plot_basic(solution)

  #add to df
two_strain_df.loc[len(two_strain_df)] = [epsilona*epsilonL,
                              epsilona,
                              epsilonL,
                              mu,
                              find_finalCIw(solution),
                              find_finalCIm(solution),
                              Iw_wave_or_end(solution),
                              find_Iw_peak(solution, Iw_wave_or_end(solution)),
                              find_Iw_equil(solution, Iw_wave_or_end(solution))]

plot_cum(solution)
# Out:
# <Axes: title={'center': 'Cumulative infections'}, xlabel='Time (days)', ylabel='Cumulative incidence'>

# %% [markdown]
# ## total natural immunity = 0 = E_a*E_L

# %%
epsilona_vals = [0, 1]
epsilonL_vals = [1, 0]
kwargs = {}
solutions = []
mu = mu_all


#loop thru epsilon values and solve to get many solutions at same protection level
for i in range(len(epsilona_vals)):
  epsilona = epsilona_vals[i]
  epsilonL = epsilonL_vals[i]
  solution = solve_ivp(SIR_model_rv,
                      [0,t],
                      y0,
                      args=(mu, betaw, gammaw, betam, gammam, epsilona, epsilonL),
                      dense_output=True,
                      t_eval=np.linspace(0, t, t + 1),)
  solutions.append(solution)
  kwargs[str(epsilona_vals[i])] = [str(epsilonL_vals[i]), solutions[i]]
  plot_basic(solution)

  #add to df
  two_strain_df.loc[len(two_strain_df)] = [epsilona*epsilonL,
                                epsilona,
                                epsilonL,
                                mu,
                                find_finalCIw(solution),
                                find_finalCIm(solution),
                                Iw_wave_or_end(solution),
                                find_Iw_peak(solution, Iw_wave_or_end(solution)),
                                find_Iw_equil(solution, Iw_wave_or_end(solution))]


plot_many_eps(two = True, ylim_max = 0.5,**kwargs)
plot_many_Mprop(ylim_max = 2,**kwargs)
plot_cum(solution)
# Out:
# <Axes: title={'center': 'Cumulative infections'}, xlabel='Time (days)', ylabel='Cumulative incidence'>

# %%
#plot for all infected indIms: relatIme freq of two strains

# %% [markdown]
# ## total natural immunity = 0.75 = E_a*E_L

# %%
epsilona_vals = [0.75, 0.9375, 0.8, 1]
epsilonL_vals = [1, 0.8, 0.9375, 0.75]
kwargs = {}
solutions = []
mu = mu_all


#loop thru epsilon values and solve to get many solutions at same protection level
for i in range(len(epsilona_vals)):
  epsilona = epsilona_vals[i]
  epsilonL = epsilonL_vals[i]
  solution = solve_ivp(SIR_model_rv,
                      [0,t],
                      y0,
                      args=(mu, betaw, gammaw, betam, gammam, epsilona_vals[i], epsilonL_vals[i]),
                      dense_output=True,
                      t_eval=np.linspace(0, t, t + 1),)
  solutions.append(solution)
  kwargs[str(epsilona_vals[i])] = [str(epsilonL_vals[i]), solutions[i]]
  plot_basic(solution)

  #add to df
  two_strain_df.loc[len(two_strain_df)] = [epsilona*epsilonL,
                                epsilona,
                                epsilonL,
                                mu,
                                find_finalCIw(solution),
                                find_finalCIm(solution),
                                Iw_wave_or_end(solution),
                                find_Iw_peak(solution, Iw_wave_or_end(solution)),
                                find_Iw_equil(solution, Iw_wave_or_end(solution))]
  #make df to add params and graph em

plot_many_eps(two = True, ylim_max = 0.3,**kwargs)
plot_many_Mprop(ylim_max = 10,**kwargs)
plot_cum(solution)
# Out:
# <Axes: title={'center': 'Cumulative infections'}, xlabel='Time (days)', ylabel='Cumulative incidence'>

# %% [markdown]
# ## total natural immunity = 0.5 = E_a*E_L

# %%
epsilona_vals = [0.5, 0.625, 0.8, 1]
epsilonL_vals = [1, 0.8, 0.625, 0.5]
kwargs = {}
solutions = []
mu = mu_all


#loop thru epsilon values and solve to get many solutions at same protection level
for i in range(len(epsilona_vals)):
  epsilona = epsilona_vals[i]
  epsilonL = epsilonL_vals[i]
  solution = solve_ivp(SIR_model_rv,
                      [0,t],
                      y0,
                      args=(mu, betaw, gammaw, betam, gammam, epsilona_vals[i], epsilonL_vals[i]),
                      dense_output=True,
                      t_eval=np.linspace(0, t, t + 1),)
  solutions.append(solution)
  kwargs[str(epsilona_vals[i])] = [str(epsilonL_vals[i]), solutions[i]]
  plot_basic(solution)

  #add to df
  two_strain_df.loc[len(two_strain_df)] = [epsilona*epsilonL,
                                epsilona,
                                epsilonL,
                                mu,
                                find_finalCIw(solution),
                                find_finalCIm(solution),
                                Iw_wave_or_end(solution),
                                find_Iw_peak(solution, Iw_wave_or_end(solution)),
                                find_Iw_equil(solution, Iw_wave_or_end(solution))]
  #make df to add params and graph em

plot_many_eps(two = True, ylim_max = 0.3,**kwargs)
plot_many_Mprop(ylim_max = 10,**kwargs)
plot_cum(solution)
# Out:
# <Axes: title={'center': 'Cumulative infections'}, xlabel='Time (days)', ylabel='Cumulative incidence'>

# %% [markdown]
# ## total natural immunity = 0.25 = E_a*E_L

# %%
##immunity overall = 0.5
epsilona_vals = [0.25, 0.4, 0.5, 0.625, 1]
epsilonL_vals = [1, 0.625, 0.5, 0.4, 0.25]
kwargs = {}
solutions = []
mu = mu_all



#loop thru epsilon values and solve to get many solutions at same protection level
for i in range(len(epsilona_vals)):
  epsilona = epsilona_vals[i]
  epsilonL = epsilonL_vals[i]
  solution = solve_ivp(SIR_model_rv,
                      [0,t],
                      y0,
                      args=(mu, betaw, gammaw, betam, gammam, epsilona_vals[i], epsilonL_vals[i]),
                      dense_output=True,
                      t_eval=np.linspace(0, t, t + 1),)
  solutions.append(solution)
  kwargs[str(epsilona_vals[i])] = [str(epsilonL_vals[i]), solutions[i]]
  plot_basic(solution)

  #add to df
  two_strain_df.loc[len(two_strain_df)] = [epsilona*epsilonL,
                                epsilona,
                                epsilonL,
                                mu,
                                find_finalCIw(solution),
                                find_finalCIm(solution),
                                Iw_wave_or_end(solution),
                                find_Iw_peak(solution, Iw_wave_or_end(solution)),
                                find_Iw_equil(solution, Iw_wave_or_end(solution))]
  #make df to add params and graph em

plot_many_eps(two = True, ylim_max = 0.3,**kwargs)
plot_many_Mprop(ylim_max = 10,**kwargs)
plot_cum(solution)
# Out:
# <Axes: title={'center': 'Cumulative infections'}, xlabel='Time (days)', ylabel='Cumulative incidence'>

# %%
one_strain_df
# Out:
#    overall_immunity  epsilon_a  epsilon_L   mu        CIw one-wave or endemic  \
# 0                 1          1          1  0.6   0.642548                wave
# 1                 0          0          1  0.6  23.456847             endemic
# 2                 0          1          0  0.6  23.456847             endemic
#
#     peak Iw  equil_Iw
# 0  0.082383       NaN
# 1       NaN     0.375
# 2       NaN     0.375

# %%
two_strain_df
# Out:
#     overall_immunity  epsilon_a  epsilon_L   mu       CIw       CIm  \
# 0               1.00     1.0000     1.0000  0.7  0.535953  0.437475
# 1               0.00     0.0000     1.0000  0.7  3.924276  0.436031
# 2               0.00     1.0000     0.0000  0.7  3.924276  0.436031
# 3               0.75     0.7500     1.0000  0.7  0.659057  0.446092
# 4               0.75     0.9375     0.8000  0.7  0.692829  0.455707
# 5               0.75     0.8000     0.9375  0.7  0.669302  0.449190
# 6               0.75     1.0000     0.7500  0.7  0.702030  0.457869
# 7               0.50     0.5000     1.0000  0.7  0.862999  0.456038
# 8               0.50     0.6250     0.8000  0.7  0.915189  0.464981
# 9               0.50     0.8000     0.6250  0.7  0.964386  0.471715
# 10              0.50     1.0000     0.5000  0.7  1.001640  0.475830
# 11              0.25     0.2500     1.0000  0.7  1.288389  0.465615
# 12              0.25     0.4000     0.6250  0.7  1.468451  0.475984
# ...

# %% [markdown]
# #HEATMAPS

# %% [markdown]
# ##goals
#
# - Is there a difference in all-or-nothing vs leaky in proportional reduction of infections? If so, what directions?
# - At what levels of immunity, R0s, and mu(?) is the difference more pronounced?
# - ^ For two strain, need to consider the possibility of how different the R0s are
# - Why does failure mode seem to matter less in two-strain scenarios?

# %%
one_strain_df = pd.DataFrame(columns=['overall_immunity', 'epsilon_a', 'epsilon_L',
                                      'mu', 'total inf_days wildtype', 'one-wave or endemic',
                                      "peak Iw", 'equil_Iw'])

two_strain_df = pd.DataFrame(columns=['overall_immunity', 'epsilon_a', 'epsilon_L',
                                      'mu', 'total reduction in inf_days wildtype',
                                      'total reduction in inf_days mutant',
                                      'total reduction in inf_days ALL',
                                      'one-wave or endemic wild', "peak Iw", 'equil_Iw',
                                      'one-wave or endemic mut', "peak Im", 'equil_Im'])

# %% [markdown]
# ## EPSILON A X OVERALL IMMUNITY HEATMAP
#
# Heatmap where epsilon A is the X axis, overall immunity is the Y, and colours are based on the total infection days reduction from no ummunity
#
# Epsilon A going from 0 to 1 in 0.5 steps.
# Overall immunity also going from 0 to 1 in 0.5 steps?
#
# *NOTE, DOESNT MAKE SENSE TO INCLUDE 0 AS A WHOLE ROW

# %%
epsilona_vals = np.linspace(0.05, 1, 20)
immunity_vals = np.linspace(0.05, 1, 20)
Rnaughts = [1, 1.5, 2, 2.5, 3, 8]

# %% [markdown]
# ####ONE STRAIN

# %%
# set parameter values (except epsilon) for all scenarios
#betaw = 1.1
Rwnaught = 1.6
gammaw = 1/14
betaw = gammaw*Rwnaught
#Rwnaught = betaw / gammaw # R0 for residents with entIwely susceptible population

mu = 0.7
t = 1000

Rmnaught = 1.6
gammam = 1/14
betam = gammam*Rmnaught

# set initial conditions
S0 = 0.999
Iw0 = 1-S0
CIw0 = 0

N0 = 0
P0 = 0

Rm0 = 0
Im0 = 0 #need to get this seeded later
y0 = [S0, Iw0, N0, P0, Im0, Rm0, CIw0, CIm0]

one_strain_df = pd.DataFrame(columns=['overall_immunity', 'epsilon_a', 'epsilon_L',
                                      'mu', "R0", 'total reduction in inf_days wildtype',
                                      'one-wave or endemic',
                                      "peak Iw", 'equil_Iw', "inf_days WT"])

for Rnaught in Rnaughts:
  #KEEP THIS IT IS THE SOLVER FOR NO PROTECTION
  solution = solve_ivp(SIR_model_rv,
                          [0,t],
                          y0,
                          args=(mu, gammaw*Rnaught, gammaw, gammam*Rnaught, gammam, 0, 0),
                          dense_output=True,
                          t_eval=np.linspace(0, t, t + 1),)

  #no immunity (no epsilons), total person days infected given specific R0
  #one number, not a series of numbers
  no_imm_totaldays_W = find_finalCIw(solution)*(1/gammaw)

  #loop thru immunities
  for eps_A in epsilona_vals:
    for overall_imm in immunity_vals:

      eps_L = (overall_imm.round(3))/(eps_A.round(3))

      #in case eps_l is too much
      if eps_L > 1:
        continue

      solution = solve_ivp(SIR_model_rv,
                        [0,t],
                        y0,
                        args=(mu, gammaw*Rnaught, gammaw, gammam*Rnaught, gammam, eps_A.round(3), eps_L),
                        dense_output=True,
                        t_eval=np.linspace(0, t, t + 1),)

      totaldays_W = find_finalCIw(solution)*(1/gammaw)
      reduction_W = (no_imm_totaldays_W - find_finalCIw(solution)*(1/gammaw))/no_imm_totaldays_W

      #add to df
      # make a dict for the new row
      new_row = {
          "overall_immunity": (eps_A*eps_L).round(3),
          "epsilon_a": eps_A.round(3),
          "epsilon_L": eps_L.round(3),
          "mu": mu,
          "R0": Rnaught,
          "total reduction in inf_days wildtype": reduction_W,
          "one-wave or endemic": Iw_wave_or_end(solution),
          "peak Iw": find_Iw_peak(solution, Iw_wave_or_end(solution)),
          "equil_Iw": find_Iw_equil(solution, Iw_wave_or_end(solution)),
          "inf_days WT": totaldays_W
      }

      # append safely?
      one_strain_df = pd.concat([one_strain_df, pd.DataFrame([new_row])], ignore_index=True)
# Out:
# /tmp/ipython-input-3273072551.py:81: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   one_strain_df = pd.concat([one_strain_df, pd.DataFrame([new_row])], ignore_index=True)

# %%
one_strain_df

# %%
#INSPECTING RELATIONSHIP BETWEEN EPSILONS AND IMMUNITY


# removed R0 loop — just inspect one heatmap
#specific R0 doesnt matter here, only looking at immunity from epsilons
filtered_df_R0 = one_strain_df[one_strain_df["R0"] == Rnaught].copy()

# avoid SettingWithCopyWarning
filtered_df_R0.loc[:, "overall_immunity"] = filtered_df_R0["overall_immunity"].round(3)
filtered_df_R0.loc[:, "epsilon_a"] = filtered_df_R0["epsilon_a"].round(3)

# create heatmap matrix
heatmap = filtered_df_R0.pivot(
    index="overall_immunity",
    columns="epsilon_a",
    values="epsilon_L"
)

# plot it
plt.figure(figsize=(6, 5))
ax = sns.heatmap(heatmap, cmap="rocket_r", vmin=-0.05, vmax=1)
ax.set_title(f"ε_L for immunity and eps_A values{t} days", pad=10)

ax.invert_yaxis()   # <-- correct

plt.tight_layout()
plt.show()
#REDUCTION IN POP SUSC, PROP OF PPL W ANY PROTECTION, ANY LEVEL OF PROTECTION

# %%
heatmaps = {}
heatmaps_total = {}

for i, r0 in enumerate(Rnaughts):
    filtered_df_R0 = one_strain_df[one_strain_df["R0"] == r0].copy()

    # avoid SettingWithCopyWarning
    filtered_df_R0.loc[:, "overall_immunity"] = filtered_df_R0["overall_immunity"].round(3)
    filtered_df_R0.loc[:, "epsilon_a"] = filtered_df_R0["epsilon_a"].round(3)

    heatmaps[i]  = filtered_df_R0.pivot(index="overall_immunity", columns="epsilon_a",
                                          values="total reduction in inf_days wildtype")
    heatmaps_total[i] = filtered_df_R0.pivot(index="overall_immunity", columns="epsilon_a",
                                          values="inf_days WT")

# %%
fig, axes = plt.subplots(1, len(Rnaughts), figsize=(4*len(Rnaughts), 5), sharex=True, sharey=True)

for i, r0 in enumerate(Rnaughts):
    ax = axes[i]
    sns.heatmap(heatmaps[i], cmap="mako_r", vmin=-0.05, vmax=1, ax=ax)
    ax.set_title(f"R0 = {r0}, prop reduction days WT for {t} days", fontsize=12, pad=10)
    ax.invert_yaxis()

plt.tight_layout()
plt.show()

# %% [markdown]
# All or nothing has greater proportional reductions in one strain, always
# 2) more pronounced at lower levels of immunity, with a very extreme flip at all-or-nothing. Differences more stark at higher R0s as well
#
# *might be bcuz of endemic equilibrium at baseline

# %%
#total days one strain
fig, axes = plt.subplots(1, len(Rnaughts), figsize=(4*len(Rnaughts), 5), sharex=True, sharey=True)

for i, r0 in enumerate(Rnaughts):
    ax = axes[i]
    sns.heatmap(heatmaps_total[i], cmap="rocket_r", vmin=0,vmax = 500, ax=ax)
    ax.set_title(f"R0 = {r0}, WT total inf_days out of {t} days", fontsize=12, pad=10)
    ax.invert_yaxis()

plt.tight_layout()
plt.show()

# %% [markdown]
# #CHECK IF THESE ENDEMIC!!!

# %% [markdown]
# ###TWO STRAIN

# %%
# set parameter values (except epsilon) for all scenarios
#betaw = 1.1
Rwnaught = 1.6
gammaw = 1/14
betaw = gammaw*Rwnaught
#Rwnaught = betaw / gammaw # R0 for residents with entIwely susceptible population

mu = 0.7
t = 1000

Rmnaught = 1.6
gammam = 1/14
betam = gammam*Rmnaught

# set initial conditions
S0 = 0.999
Iw0 = 0.0009

N0 = 0
P0 = 0

Rm0 = 0
Im0 = 1-(S0+Iw0+N0+P0+Rm0) #need to get this seeded later
y0 = [S0, Iw0, N0, P0, Im0, Rm0, CIw0, CIm0]

two_strain_df = pd.DataFrame(columns=['overall_immunity', 'epsilon_a', 'epsilon_L',
                                      'mu', 'R0','total reduction in inf_days wildtype',
                                      'total reduction in inf_days mutant',
                                      'total reduction in inf_days ALL',
                                      'one-wave or endemic wild', "peak Iw", 'equil_Iw',
                                      'one-wave or endemic mut', "peak Im", 'equil_Im',
                                      'inf_days wildtype',
                                      'inf_days mutant'])


#loop thru r0s and solve w characteristics, put in df
for Rnaught in Rnaughts:
  solution = solve_ivp(SIR_model_rv,
                        [0,t],
                        y0,
                        args=(mu, gammaw*Rnaught, gammaw, gammam*Rnaught, gammam, 0, 0),
                        dense_output=True,
                        t_eval=np.linspace(0, t, t + 1),)

  no_imm_totaldays_W = find_finalCIw(solution)*(1/gammaw)
  no_imm_totaldays_M =  find_finalCIm(solution)*(1/gammam)
  no_imm_totaldays_ALL = no_imm_totaldays_W+no_imm_totaldays_M

  for eps_A in epsilona_vals:
    for overall_imm in immunity_vals:
      eps_L = (overall_imm.round(3))/(eps_A.round(3))

      #not all epsilons are valid
      if eps_L > 1:
        continue
      solution = solve_ivp(SIR_model_rv,
                        [0,t],
                        y0,
                        args=(mu, gammaw*Rnaught, gammaw, gammam*Rnaught, gammam, eps_A.round(3), eps_L),
                        dense_output=True,
                        t_eval=np.linspace(0, t, t + 1),)

      total_infected_days_W = find_finalCIw(solution)*(1/gammaw)
      total_infected_days_M = find_finalCIm(solution)*(1/gammam)
      total_infected_days_WM = total_infected_days_W + total_infected_days_M


      totalred_days_W = (no_imm_totaldays_W - total_infected_days_W)/no_imm_totaldays_W
      totalred_days_M = (no_imm_totaldays_M - total_infected_days_M)/no_imm_totaldays_M

      total_reduction_days = (no_imm_totaldays_ALL - total_infected_days_WM)/no_imm_totaldays_ALL

      #add to df
      two_strain_df.loc[len(two_strain_df)] = [overall_imm.round(3),
                                    eps_A.round(3),
                                    eps_L,
                                    mu,
                                    Rnaught,
                                    totalred_days_W,
                                    totalred_days_M,
                                    total_reduction_days,
                                    Iw_wave_or_end(solution),
                                    find_Iw_peak(solution, Iw_wave_or_end(solution)),
                                    find_Iw_equil(solution, Iw_wave_or_end(solution)),
                                    Im_wave_or_end(solution),
                                    find_Im_peak(solution, Im_wave_or_end(solution)),
                                    find_Im_equil(solution, Im_wave_or_end(solution)),
                                    total_infected_days_W,
                                    total_infected_days_M
                                    ]

# %%
heatmaps_W = {}
heatmaps_M = {}
heatmaps_MW = {}
heatmaps_totalW = {}
heatmaps_totalM = {}

for i, r0 in enumerate(Rnaughts):
    filtered_df_R0 = two_strain_df[two_strain_df["R0"] == r0].copy()

    # avoid SettingWithCopyWarning
    filtered_df_R0.loc[:, "overall_immunity"] = filtered_df_R0["overall_immunity"].round(3)
    filtered_df_R0.loc[:, "epsilon_a"] = filtered_df_R0["epsilon_a"].round(3)

    heatmaps_W[i]  = filtered_df_R0.pivot(index="overall_immunity", columns="epsilon_a",
                                          values="total reduction in inf_days wildtype")

    heatmaps_M[i]  = filtered_df_R0.pivot(index="overall_immunity", columns="epsilon_a",
                                          values="total reduction in inf_days mutant")

    heatmaps_MW[i] = filtered_df_R0.pivot(index="overall_immunity", columns="epsilon_a",
                                          values="total reduction in inf_days ALL")

    heatmaps_totalW[i] = filtered_df_R0.pivot(index="overall_immunity", columns="epsilon_a",
                                          values="inf_days wildtype")

    heatmaps_totalM[i] = filtered_df_R0.pivot(index="overall_immunity", columns="epsilon_a",
                                          values="inf_days mutant")

# %%
#total days WT
fig, axes = plt.subplots(1, len(Rnaughts), figsize=(4*len(Rnaughts), 5), sharex=True, sharey=True)

for i, r0 in enumerate(Rnaughts):
    ax = axes[i]
    sns.heatmap(heatmaps_totalW[i], cmap="rocket_r", vmin=0,vmax = 100, ax=ax)
    ax.set_title(f"R0 = {r0}, WT total inf_days for {t} days", fontsize=12, pad=10)
    ax.invert_yaxis()

plt.tight_layout()
plt.show()

# %%
#total days mutant
fig, axes = plt.subplots(1, len(Rnaughts), figsize=(4*len(Rnaughts), 5), sharex=True, sharey=True)

for i, r0 in enumerate(Rnaughts):
    ax = axes[i]
    sns.heatmap(heatmaps_totalM[i], cmap="rocket_r", vmin = 0, vmax = 100, ax=ax)
    ax.set_title(f"R0 = {r0}, mut total inf_days out of {t} days", fontsize=12, pad=10)
    ax.invert_yaxis()

plt.tight_layout()
plt.show()

#total days mutant
fig, axes = plt.subplots(1, len(Rnaughts), figsize=(4*len(Rnaughts), 5), sharex=True, sharey=True)

for i, r0 in enumerate(Rnaughts):
    ax = axes[i]
    sns.heatmap(heatmaps_totalM[i], cmap="rocket_r", vmin = 0, vmax = 10, ax=ax)
    ax.set_title(f"R0 = {r0}, mut total inf_days out of {t} days", fontsize=12, pad=10)
    ax.invert_yaxis()

plt.tight_layout()
plt.show()

# %%
#WT reductions
fig, axes = plt.subplots(1, len(Rnaughts), figsize=(4*len(Rnaughts), 5), sharex=True, sharey=True)

for i, r0 in enumerate(Rnaughts):
    ax = axes[i]
    sns.heatmap(heatmaps_W[i], cmap="mako_r", vmin=-0.1, vmax=1, ax=ax)
    ax.set_title(f"R0 = {r0}, t = {t}, WT reduc's in total inf_days", fontsize=12, pad=10)
    ax.invert_yaxis()

plt.tight_layout()
plt.show()

# %% [markdown]
# for WT: all-or-nothing has greater proportional reductions, no intermediate values, and 2) mostly at lower immunities and higher R0
#
# overall, immunity is the driving factor for proportional reduction in infected days

# %%
#MUTANT reductions
fig, axes = plt.subplots(1, len(Rnaughts), figsize=(4*len(Rnaughts), 5), sharex=True, sharey=True)

for i, r0 in enumerate(Rnaughts):
    ax = axes[i]
    sns.heatmap(heatmaps_M[i], cmap="mako_r", vmin=-0.1, vmax=1, ax=ax)
    ax.set_title(f"R0 = {r0}, t = {t}, mut reduc' in total inf_days", fontsize=12, pad=10)
    ax.invert_yaxis()

plt.tight_layout()
plt.show()

# %% [markdown]
# Note the different scale, but same parameters below.

# %%
fig, axes = plt.subplots(1, len(Rnaughts), figsize=(4*len(Rnaughts), 5), sharex=True, sharey=True)

for i, r0 in enumerate(Rnaughts):
    ax = axes[i]
    sns.heatmap(heatmaps_M[i], cmap="icefire", vmin = -0.1, vmax=0.1, ax=ax)
    ax.set_title(f"R0 = {r0}, t = {t}, mut reduc's' in total inf_days", fontsize=12, pad=10)
    ax.invert_yaxis()

plt.tight_layout()
plt.show()

# %% [markdown]
# that the pattern is mostly INVERSE of the pattern in WT > suggesting theres some inverse relationship between infections WT and mutant. Plus, most of these are NEGATIVE, meaning that having immunity is WORSE than baseline (more infected person days relative to no immunity).

# %%
#WT+mut reductions
fig, axes = plt.subplots(1, len(Rnaughts), figsize=(4*len(Rnaughts), 5), sharex=True, sharey=True)

for i, r0 in enumerate(Rnaughts):
    ax = axes[i]
    sns.heatmap(heatmaps_MW[i], cmap="mako_r", vmin=-0.1, vmax=1, ax=ax)
    ax.set_title(f"R0 = {r0}, WT+mut reductions in total inf_days", fontsize=12, pad=10)
    ax.invert_yaxis()

plt.tight_layout()
plt.show()

# %% [markdown]
# Note that the WT infections dominate heatmaps, way more days to think ab

# %% [markdown]
# ## DISTINCT HETMAPS

# %% [markdown]
# #### GENERATING HEATMAPS ON THEIR OWN - ONE STRAIN

# %%
ax = sns.heatmap(heatmaps[0], cmap="mako_r", vmin=-0.05, vmax=1)
ax.set_title("reduction in inf_days for immunity and eps_A values", pad=10)

ax.invert_yaxis()

# %% [markdown]
# #### GENERATING HEATMAPS ON THEIR OWN - TWO STRAIN

# %%
heatmaps_W = {}
heatmaps_M = {}
heatmaps_MW = {}

for i in range(len(Rnaughts)):
  filtered_df_R0 = two_strain_df[two_strain_df['R0'] == Rnaughts[i]]
  #just to make sure numbers are 0.05 steps
  filtered_df_R0["overall_immunity"] = filtered_df_R0["overall_immunity"].round(3)
  filtered_df_R0["epsilon_a"] = filtered_df_R0["epsilon_a"].round(3)
  filtered_df_R0

  heatmaps_W[i] = filtered_df_R0.pivot(index="overall_immunity", columns="epsilon_a", values="total reduction in inf_days wildtype")
  heatmaps_M[i] = filtered_df_R0.pivot(index="overall_immunity", columns="epsilon_a", values="total reduction in inf_days mutant")
  heatmaps_MW[i] = filtered_df_R0.pivot(index="overall_immunity", columns="epsilon_a", values="total reduction in inf_days ALL")

# %%
ax = sns.heatmap(heatmaps_M[1], cmap="mako_r", vmin=-0.1, vmax=0.03) #change the index within heatmaps[]
ax.set_title("reduction in inf_day WT for immunity and eps_A values")
ax.invert_yaxis()

# %% [markdown]
# ## INVESTIGATING TWO STRAIN DYNAMICS
# of interest:
#
# R0 = 1.5 has interesting reductions, seems like intermediate levels of immunity failure are worse (see below)
#
# wild type and mutants have similar total infected days
#
# so by picking numbers for R0 = 1.5 2.5, and 8, can get a sense of wy=hy total infected days are similar and if its the same reason throughout R0
#
# and by picking epsilon immunities that are within zones of interest, we can see if theres anything interesting going on within those dynamics (see red lines)
#
# also need to hold immunity constantm perhaps at 0.15?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###holding eps_A constant

# %%
# set parameter values (except epsilon) for all scenarios
gammaw = 1/14

mu = 0.7
t = 1000

gammam = 1/14

Rnaughtss = [1.5, 2.5, 8]
immunity_vals = [0.9, 0.55, 0.25, 0.05]

eps_A = 0.9

# set initial conditions
S0 = 0.999
Iw0 = 0.0009

N0 = 0
P0 = 0

Rm0 = 0
Im0 = 1-(S0+Iw0+N0+P0+Rm0) #need to get this seeded later
y0 = [S0, Iw0, N0, P0, Im0, Rm0, CIw0, CIm0]

# %%
#BASELINE NO IMM
Rnaught = Rnaughtss[0]
t = 1000
solution = solve_ivp(
      SIR_model_rv,
      [0, t],
      y0,
      args=(mu, gammaw*Rnaught, gammaw,
            gammam*Rnaught, gammam,
            0, 0),
      dense_output=True,
      t_eval=np.linspace(0, t, t + 1),
  )

fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharex=True)

plot_basic(
    solution,
    ax=axes[0],
    title=f"R0={Rnaught}, eps_A=0, eps_L = 0, imm=0")

plot_cum(
    solution,
    ax=axes[1],
    title="Cumulative",
    ylim_max = 4
)

plt.tight_layout()
plt.show()

# %%
Rnaught = Rnaughtss[0]
t = 1000
#special case

for i in range(len(immunity_vals)):
    overall_imm = immunity_vals[i]
    eps_L = round(overall_imm, 3) / round(eps_A, 3)

    solution = solve_ivp(
        SIR_model_rv,
        [0, t],
        y0,
        args=(mu, gammaw*Rnaught, gammaw,
              gammam*Rnaught, gammam,
              round(eps_A, 3), eps_L),
        dense_output=True,
        t_eval=np.linspace(0, t, t + 1),
    )

    fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharex=True)

    plot_basic(
        solution,
        ax=axes[0],
        title=f"R0={Rnaught}, eps_A={eps_A}, eps_L = {round(eps_L, 3)}, imm={overall_imm}, "
    )

    plot_cum(
        solution,
        ax=axes[1],
        title="Cumulative",
        ylim_max = 4
    )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Note that infected WT days/CIw is much higher for no immunity baseline. Proportional reduction in mutant is better (higher) at high immunity, but also at very low immunities. This is likely because there is no coinfection: the advantage afforded to Iw due to increased prevalence (starting) outweighs the advantage afforded from immune escape (mu)

# %%
Rnaught = Rnaughtss[1]

for i in range(len(immunity_vals)):
    overall_imm = immunity_vals[i]
    eps_L = round(overall_imm, 3) / round(eps_A, 3)

    solution = solve_ivp(
        SIR_model_rv,
        [0, t],
        y0,
        args=(mu, gammaw*Rnaught, gammaw,
              gammam*Rnaught, gammam,
              round(eps_A, 3), eps_L),
        dense_output=True,
        t_eval=np.linspace(0, t, t + 1),
    )

    fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharex=True)

    plot_basic(
        solution,
        ax=axes[0],
        title=f"R0={Rnaught}, eps_A={eps_A}, eps_L = {round(eps_L, 3)}, imm={overall_imm}, "
    )

    plot_cum(
        solution,
        ax=axes[1],
        title="Cumulative",
        ylim_max = 4
    )

    plt.tight_layout()
    plt.show()

# %%
Rnaught = Rnaughtss[2]
t = 200 #can see things stabilize before this point

for i in range(len(immunity_vals)):
    overall_imm = immunity_vals[i]
    eps_L = round(overall_imm, 3) / round(eps_A, 3)

    solution = solve_ivp(
        SIR_model_rv,
        [0, t],
        y0,
        args=(mu, gammaw*Rnaught, gammaw,
              gammam*Rnaught, gammam,
              round(eps_A, 3), eps_L),
        dense_output=True,
        t_eval=np.linspace(0, t, t + 1),
    )

    fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharex=True)

    plot_basic(
        solution,
        ax=axes[0],
        title=f"R0={Rnaught}, eps_A={eps_A}, eps_L = {round(eps_L, 3)}, imm={overall_imm}, "
    )

    plot_cum(
        solution,
        ax=axes[1],
        title="Cumulative",
        ylim_max = 4
    )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# R0 higher than 1.5 show similar pattern, with greater CIw being the main difference between immunities, and the least CIm being with greater CIw

# %% [markdown]
# ### holding imm constant
# (see black lines)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# set parameter values (except epsilon) for all scenarios
gammaw = 1/14

mu = 0.7
t = 1000

gammam = 1/14

Rnaughtss = [1.5, 2.5, 8]
overall_imm = 0.15

epsilona_vals = [0.15, 0.2, 0.55, 0.95, 1]

# set initial conditions
S0 = 0.999
Iw0 = 0.0009

N0 = 0
P0 = 0

Rm0 = 0
Im0 = 1-(S0+Iw0+N0+P0+Rm0) #need to get this seeded later
y0 = [S0, Iw0, N0, P0, Im0, Rm0, CIw0, CIm0]

# %%
Rnaught = Rnaughtss[0]
t = 1000
#special case

for i in range(len(epsilona_vals)):
    eps_A = epsilona_vals[i]
    eps_L = round(overall_imm, 3) / round(eps_A, 3)

    solution = solve_ivp(
        SIR_model_rv,
        [0, t],
        y0,
        args=(mu, gammaw*Rnaught, gammaw,
              gammam*Rnaught, gammam,
              round(eps_A, 3), eps_L),
        dense_output=True,
        t_eval=np.linspace(0, t, t + 1),
    )

    fig, axes = plt.subplots(1, 2, figsize=(14, 5), sharex=True)

    plot_basic(
        solution,
        ax=axes[0],
        title=f"R0={Rnaught}, eps_A={eps_A}, eps_L = {round(eps_L, 3)}, imm={overall_imm}, "
    )

    plot_cum(
        solution,
        ax=axes[1],
        title="Cumulative",
        ylim_max = 5
    )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# Holding imm constant, seems like similar result
